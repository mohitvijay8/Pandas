# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv("adult.csv")
data1
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data1.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
data1.tail(10)
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 48832   32       Private   34066          10th                6
# 48833   43       Private   84661     Assoc-voc               11
# 48834   32       Private  116138       Masters               14
# 48835   53       Private  321865       Masters               14
# 48836   22       Private  310152  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 48832  Married-civ-spouse  Handlers-cleaners        Husband
# 48833  Married-civ-spouse              Sales        Husband
# 48834       Never-married       Tech-support  Not-in-family
# ...

# %%
data1.shape
# Out:
# (48842, 15)

# %%
print("number of rows: ",data1.shape[0])
print("number of columns: ",data1.shape[1])
# Out:
# number of rows:  48842
# number of columns:  15

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data1.isnull().sum()    # to find number of null values in each columns
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data1.sample(frac= 0.5, random_state=100)     # to fetch random samples from the dataset to get 50% we used frac = 0.5  and  random_state=100 is used to get same random dataset again and again
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %%
data1.isin(["?"]).sum()   # to check ? is present in how many columns in dataset
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
data1["workclass"]=data1["workclass"].replace("?",np.nan)      # replaced ? with nan value
data1["occupation"] = data1["occupation"].replace("?",np.nan)
data1["native-country"]=data1["native-country"].replace("?",np.nan)

# %%
data1.isin(["?"]).sum()        #
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
per_missing_values = data1.isnull().sum()*100/len(data1)
per_missing_values
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %%
data1.dropna(how='any',inplace=True)   # to drop nan values in dataset, how='any' will check if any nan value in row then remove whole row and inplace will do the changes in given dataset.

# %%
data1.shape
# Out:
# (48842, 15)

# %%
48842-45222    # number of rows removed after dropping nan values row
# Out:
# 3620

# %%
dup  =data1.duplicated().any()         # to check if any duplicate value present in whole dataset
dup
# Out:
# False

# %%
print("any duplicated value in dataset: ", dup)
# Out:
# any duplicated value in dataset:  True

# %%
data1= data1.drop_duplicates()

# %%
data1
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data1.shape
# Out:
# (48790, 15)

# %%
45222-45175

# %%
data1.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48790.000000     48790  4.879000e+04     48790     48790.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33860           NaN     15770              NaN
# mean       38.652798       NaN  1.896690e+05       NaN        10.078807
# std        13.708493       NaN  1.056172e+05       NaN         2.570046
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175550e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781385e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376062e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
data1.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data1.drop(['educational-num','capital-gain','capital-loss'],axis=1)    # to drop columns from dataset
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 0       25       Private  226802          11th       Never-married
# 1       38       Private   89814       HS-grad  Married-civ-spouse
# 2       28     Local-gov  336951    Assoc-acdm  Married-civ-spouse
# 3       44       Private  160323  Some-college  Married-civ-spouse
# 4       18             ?  103497  Some-college       Never-married
# ...    ...           ...     ...           ...                 ...
# 48837   27       Private  257302    Assoc-acdm  Married-civ-spouse
# 48838   40       Private  154374       HS-grad  Married-civ-spouse
# 48839   58       Private  151910       HS-grad             Widowed
# 48840   22       Private  201490       HS-grad       Never-married
# 48841   52  Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct    Own-child  Black    Male              40
# ...

# %%
# find distribution of age column
data1['age'].describe()
# Out:
# count    48790.000000
# mean        38.652798
# std         13.708493
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
data1['age'].hist()
# Out:
# <AxesSubplot:>

# %%
data1[(data1['age']>=17)  & (data1['age']<=48)]   # data for age between 17 and 48 included
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 48834   32    Private  116138       Masters               14
# 48836   22    Private  310152  Some-college               10
# 48837   27    Private  257302    Assoc-acdm               12
# 48838   40    Private  154374       HS-grad                9
# 48840   22    Private  201490       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 0           Never-married  Machine-op-inspct      Own-child
# 1      Married-civ-spouse    Farming-fishing        Husband
# ...

# %%
sum((data1['age']>=17) & (data1['age']<=48))     # sum method to find number of rows, which is also equal to number of person with 48>age>17
# Out:
# 37272

# %%
sum(data1['age'].between(17,48))   # between includes both the range values
# Out:
# 37272

# %%
# distribution of workclass column
data1["workclass"].describe(include = 'all')
# Out:
# count       48790
# unique          9
# top       Private
# freq        33860
# Name: workclass, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
data1['workclass'].hist()
# Out:
# <AxesSubplot:>

# %%
data1.head(13)

# %%
data1[(data1['education'] == 'Bachelors')  | (data1['education'] == 'Masters')]
# Out:
#        age    workclass  fnlwgt  education  educational-num  \
# 11      36  Federal-gov  212465  Bachelors               13
# 15      43      Private  346189    Masters               14
# 20      34      Private  107914  Bachelors               13
# 23      25      Private  220931  Bachelors               13
# 24      25      Private  205947  Bachelors               13
# ...    ...          ...     ...        ...              ...
# 48817   34      Private  160216  Bachelors               13
# 48819   38      Private  139180  Bachelors               13
# 48825   31      Private  199655    Masters               14
# 48834   32      Private  116138    Masters               14
# 48835   53      Private  321865    Masters               14
#
#            marital-status       occupation   relationship                race  \
# 11     Married-civ-spouse     Adm-clerical        Husband               White
# 15     Married-civ-spouse  Exec-managerial        Husband               White
# ...

# %%
len(data1[(data1['education'] == 'Bachelors')  | (data1['education'] == 'Masters')])
# Out:
# 10669

# %%
len(data1[data1['education'].isin(['Bachelors','Masters'])])

# %%
def salary_data(sal):
    if sal == '>50K':
        return 1
    else:
        return 0

# %%
data1['encoded_income']=data1['income'].apply(salary_data)
# Out:
# C:\Users\Welcome\AppData\Local\Temp/ipykernel_3520/686238748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['encoded_income']=data1['income'].apply(salary_data)

# %%
data1.head(1)
# Out:
#    age workclass  fnlwgt education  educational-num marital-status  \
# 0   25   Private  226802      11th                7  Never-married
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
#
#    hours-per-week native-country income  encoded_income
# 0              40  United-States  <=50K               0

# %%
data1.replace(['>50K','<=50K'],[1,0])  #another one
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data1['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data1.groupby('workclass')['encoded_income'].mean().sort_values(ascending=False)
# Out:
# workclass
# Self-emp-inc        0.553719
# Federal-gov         0.391760
# Local-gov           0.295599
# Self-emp-not-inc    0.278943
# State-gov           0.267542
# Private             0.217986
# Without-pay         0.095238
# ?                   0.094812
# Never-worked        0.000000
# Name: encoded_income, dtype: float64

# %%
data1.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income', 'encoded_income'],
#       dtype='object')

# %%
data1.groupby('gender')['encoded_income'].mean().max()
# Out:
# 0.3039185625804869

# %%
data1['workclass']=data1['workclass'].astype('category')
# Out:
# C:\Users\Welcome\AppData\Local\Temp/ipykernel_3520/3206589815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['workclass']=data1['workclass'].astype('category')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48790 entries, 0 to 48841
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48790 non-null  int64
#  1   workclass        48790 non-null  category
#  2   fnlwgt           48790 non-null  int64
#  3   education        48790 non-null  object
#  4   educational-num  48790 non-null  int64
#  5   marital-status   48790 non-null  object
#  6   occupation       48790 non-null  object
#  7   relationship     48790 non-null  object
#  8   race             48790 non-null  object
#  9   gender           48790 non-null  object
#  10  capital-gain     48790 non-null  int64
#  11  capital-loss     48790 non-null  int64
#  12  hours-per-week   48790 non-null  int64
#  13  native-country   48790 non-null  object
#  14  income           48790 non-null  object
#  15  encoded_income   48790 non-null  int64
# dtypes: category(1), int64(7), object(8)
# ...

# %%
data1.shape
# Out:
# (48790, 16)
