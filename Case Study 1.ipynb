# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv("Ecommerce Purchases1")

# %%
data1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
data1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Credit Card'}>,
#         <AxesSubplot:title={'center':'CC Security Code'}>],
#        [<AxesSubplot:title={'center':'Purchase Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data1.head(10)

# %%
data1.tail(10)

# %%
data1.dtypes    # to check dattatype of each column
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
data1.isnull().sum()    # to count number of null values in columns
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
data1.shape

# %%
len(data1.columns)    #number of columns

# %%
len(data1)    # this will give the number of rows which is len of total data

# %%
data1.info()

# %%
data1.head(5)

# %%
data1["Purchase Price"].max()   # max purchase price

# %%
data1["Purchase Price"].min()   # min price

# %%
data1["Purchase Price"].mean()

# %%
data1[data1["Language"] == "fr"].count()     # people with "fr" as language
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %%
len(data1[data1["Language"] == "fr"])    # people with "fr" as language
# Out:
# 1097

# %%
data1.columns

# %%
len(data1[data1['Job'].str.contains("engineer", case=False)])

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data1.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
data1[data1["IP Address"] == "132.207.160.22"]["Email"]    # email for the given ip address
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
len(data1[(data1['AM or PM']=='PM')  & (data1['CC Provider']=='Mastercard')])
# Out:
# 438

# %%
data1[(data1["CC Provider"] == "Mastercard") & (data1["Purchase Price"] > 50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(data1[(data1["CC Provider"] == "Mastercard") & (data1["Purchase Price"] > 50)]) #
# Out:
# 405

# %%
data1.head(3)

# %%
data1["AM or PM"].value_counts()    # value_counts() method is used to find number of occurence of perticular values in column
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
data1.head(3)

# %%
data1.sort_values('Purchase Price',ascending= False)
# Out:
#                                                 Address    Lot AM or PM  \
# 2092          63773 Shelton Greens\nAshleyton, MA 00493  56 lu       AM
# 7807              PSC 6177, Box 1004\nAPO AA 57143-1269  64 Nf       AM
# 9856  058 Miranda Locks Suite 792\nPort Davidstad, P...  73 IW       PM
# 7604            672 James Oval\nNew Davidview, KS 91202  07 dT       PM
# 3844  27148 Kathy Cliff Apt. 400\nEast Jillton, TX 5...  37 ou       PM
# ...                                                 ...    ...      ...
# 2783  402 Joseph Tunnel Apt. 219\nMartinmouth, DE 58480  46 Yg       AM
# 8656          146 Laura Mission\nNorth Donald, NC 76608  95 xb       PM
# 6863     9202 Baker Forks\nNew Chelseaborough, VA 70852  40 Vx       AM
# 2876  332 Jones Parkways\nEast Katherineville, GA 64230  39 GT       AM
# 5487     465 Mallory Ways\nNorth Rebecca, RI 82734-1160  93 OH       PM
#
#                                            Browser Info  \
# ...

# %%
data1[data1["CC Exp Date"].str.contains("20")].count()
# Out:
# Address             988
# Lot                 988
# AM or PM            988
# Browser Info        988
# Company             988
# Credit Card         988
# CC Exp Date         988
# CC Security Code    988
# CC Provider         988
# Email               988
# Job                 988
# IP Address          988
# Language            988
# Purchase Price      988
# dtype: int64

# %%
data1["Email"]
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
list1= []
for email in data1["Email"]:
    list1.append(email.split("@")[1])

# %%
data1["temp"] = list1

# %%
data1["temp"].value_counts()    # to fing top 5 mail provider in email
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: temp, Length: 3416, dtype: int64

# %%
data1.insert
# Out:
# <bound method DataFrame.insert of                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...
